# %% [markdown]
# # 00_Intro #
# #### - dcm 파일을 처음 열어봄.
# #### - 자료를 전부 열어서 확인함.

# %%
import pydicom
import matplotlib.pyplot as plt

# DICOM 파일 경로 설정
file_path = '/Users/yuna/tumorpred/Data/manifest-1542731028231/Brain-Tumor-Progression/PGBM-001/04-02-1992-NA-FH-HEADBrain Protocols-79896/11.000000-T1post-80644/1-01.dcm'

# DICOM 파일 읽기
dataset = pydicom.dcmread(file_path)

# 이미지 데이터 접근 및 시각화
plt.imshow(dataset.pixel_array, cmap='gray')
plt.axis('off')  # 축 없애기
plt.show()

# %%
# 컬러맵 적용하여 시각화
plt.imshow(dataset.pixel_array, cmap='viridis')  # cmap='jet' 또는 다른 컬러맵으로도 가능
plt.axis('off')  # 축 없애기
plt.show()

# %%
import pydicom
import matplotlib.pyplot as plt
import os

# 각 시퀀스 폴더 경로
sequence_folders = [
    'Data/manifest-1542731028231/Brain-Tumor-Progression/PGBM-001/11-19-1991-NA-FH-HEADBrain Protocols-40993/10008.000000-T1prereg-91470',
    'Data/manifest-1542731028231/Brain-Tumor-Progression/PGBM-001/04-02-1992-NA-FH-HEADBrain Protocols-79896/34907.000000-T1prereg-43695', 
    'Data/manifest-1542731028231/Brain-Tumor-Progression/PGBM-001/11-19-1991-NA-FH-HEADBrain Protocols-40993/11.000000-T1post-03326', 
    'Data/manifest-1542731028231/Brain-Tumor-Progression/PGBM-001/04-02-1992-NA-FH-HEADBrain Protocols-79896/11.000000-T1post-80644', 
    'Data/manifest-1542731028231/Brain-Tumor-Progression/PGBM-001/11-19-1991-NA-FH-HEADBrain Protocols-40993/35004.000000-dT1-72693', 
    'Data/manifest-1542731028231/Brain-Tumor-Progression/PGBM-001/04-02-1992-NA-FH-HEADBrain Protocols-79896/29904.000000-dT1-04743',  
    'Data/manifest-1542731028231/Brain-Tumor-Progression/PGBM-001/11-19-1991-NA-FH-HEADBrain Protocols-40993/35633.000000-nCBFreg-34937',
    'Data/manifest-1542731028231/Brain-Tumor-Progression/PGBM-001/04-02-1992-NA-FH-HEADBrain Protocols-79896/35630.000000-nCBFreg-63461', 
    'Data/manifest-1542731028231/Brain-Tumor-Progression/PGBM-001/11-19-1991-NA-FH-HEADBrain Protocols-40993/35634.000000-nRCBVreg-43858',
    'Data/manifest-1542731028231/Brain-Tumor-Progression/PGBM-001/04-02-1992-NA-FH-HEADBrain Protocols-79896/35629.000000-nRCBVreg-30349', 
    'Data/manifest-1542731028231/Brain-Tumor-Progression/PGBM-001/11-19-1991-NA-FH-HEADBrain Protocols-40993/35635.000000-sRCBVreg-60307',
    'Data/manifest-1542731028231/Brain-Tumor-Progression/PGBM-001/04-02-1992-NA-FH-HEADBrain Protocols-79896/35628.000000-sRCBVreg-27603',
    'Data/manifest-1542731028231/Brain-Tumor-Progression/PGBM-001/11-19-1991-NA-FH-HEADBrain Protocols-40993/35638.000000-ADCreg-71556', 
    'Data/manifest-1542731028231/Brain-Tumor-Progression/PGBM-001/04-02-1992-NA-FH-HEADBrain Protocols-79896/35624.000000-ADCreg-47789', 
    'Data/manifest-1542731028231/Brain-Tumor-Progression/PGBM-001/11-19-1991-NA-FH-HEADBrain Protocols-40993/37910.000000-T2reg-84816',
    'Data/manifest-1542731028231/Brain-Tumor-Progression/PGBM-001/04-02-1992-NA-FH-HEADBrain Protocols-79896/37908.000000-T2reg-21119',
    'Data/manifest-1542731028231/Brain-Tumor-Progression/PGBM-001/11-19-1991-NA-FH-HEADBrain Protocols-40993/5364.000000-MaskTumor-94345',
    'Data/manifest-1542731028231/Brain-Tumor-Progression/PGBM-001/04-02-1992-NA-FH-HEADBrain Protocols-79896/5388.000000-MaskTumor-63335'
]

# 각 폴더에 대해 4줄 x 5열 배열로 시각화
for folder_path in sequence_folders:
    # 새로운 figure 생성 (4줄 x 5열)
    fig, axs = plt.subplots(4, 5, figsize=(15, 12))  # 4줄, 5열로 20개 subplot
    axs = axs.flatten()  # 2D 배열을 1D 배열로 변환해 순차적으로 접근

    # 폴더 이름을 표시
    folder_name = os.path.basename(os.path.normpath(folder_path))  # 폴더 이름 추출
    fig.suptitle(f"Folder: {folder_name}", fontsize=16)

    # 각 폴더에서 최대 20개 DICOM 파일을 열어봅니다.
    for i, file_name in enumerate(sorted(os.listdir(folder_path))[:20]):  # 각 폴더에서 최대 20개 파일 시각화
        file_path = os.path.join(folder_path, file_name)
        
        # DICOM 파일 읽기 및 시각화
        try:
            dataset = pydicom.dcmread(file_path)
            axs[i].imshow(dataset.pixel_array, cmap='gray')  # 이미지를 흑백으로 표시
            axs[i].axis('off')  # 축 없애기
            axs[i].set_title(f"{file_name}", fontsize=8)  # 파일 이름을 제목으로 표시
        except Exception as e:
            print(f"Error reading {file_name} in folder {folder_path}: {e}")
            axs[i].axis('off')
            axs[i].set_title(f"Error {file_name}", fontsize=8)

    plt.tight_layout()
    plt.show()

# %%
# 각 시퀀스 폴더 경로
sequence_folders = [
    'Data/manifest-1542731028231/Brain-Tumor-Progression/PGBM-002/08-13-1996-NA-Mr Rcbv Sequence-46313/11.000000-T1post-73420',
    'Data/manifest-1542731028231/Brain-Tumor-Progression/PGBM-002/01-17-1997-NA-MR RCBV SEQUENCE-36058/12.000000-T1post-05670',
    'Data/manifest-1542731028231/Brain-Tumor-Progression/PGBM-002/08-13-1996-NA-Mr Rcbv Sequence-46313/14409.000000-dT1-29077',
    'Data/manifest-1542731028231/Brain-Tumor-Progression/PGBM-002/01-17-1997-NA-MR RCBV SEQUENCE-36058/29905.000000-dT1-93274',
    'Data/manifest-1542731028231/Brain-Tumor-Progression/PGBM-002/08-13-1996-NA-Mr Rcbv Sequence-46313/19446.000000-T1prereg-51935',
    'Data/manifest-1542731028231/Brain-Tumor-Progression/PGBM-002/01-17-1997-NA-MR RCBV SEQUENCE-36058/34909.000000-T1prereg-84610',
    'Data/manifest-1542731028231/Brain-Tumor-Progression/PGBM-002/08-13-1996-NA-Mr Rcbv Sequence-46313/36449.000000-FLAIRreg-98695',
    'Data/manifest-1542731028231/Brain-Tumor-Progression/PGBM-002/01-17-1997-NA-MR RCBV SEQUENCE-36058/36459.000000-FLAIRreg-76244',
    'Data/manifest-1542731028231/Brain-Tumor-Progression/PGBM-002/08-13-1996-NA-Mr Rcbv Sequence-46313/36450.000000-ADCreg-95934',
    'Data/manifest-1542731028231/Brain-Tumor-Progression/PGBM-002/01-17-1997-NA-MR RCBV SEQUENCE-36058/36460.000000-ADCreg-72331',
    'Data/manifest-1542731028231/Brain-Tumor-Progression/PGBM-002/08-13-1996-NA-Mr Rcbv Sequence-46313/36454.000000-nRCBVreg-37925',
    'Data/manifest-1542731028231/Brain-Tumor-Progression/PGBM-002/01-17-1997-NA-MR RCBV SEQUENCE-36058/36465.000000-nRCBVreg-26072',
    'Data/manifest-1542731028231/Brain-Tumor-Progression/PGBM-002/08-13-1996-NA-Mr Rcbv Sequence-46313/36455.000000-sRCBVreg-00481',
    'Data/manifest-1542731028231/Brain-Tumor-Progression/PGBM-002/01-17-1997-NA-MR RCBV SEQUENCE-36058/36463.000000-sRCBVreg-80726',
    'Data/manifest-1542731028231/Brain-Tumor-Progression/PGBM-002/08-13-1996-NA-Mr Rcbv Sequence-46313/36456.000000-nCBFreg-05909',
    'Data/manifest-1542731028231/Brain-Tumor-Progression/PGBM-002/01-17-1997-NA-MR RCBV SEQUENCE-36058/36464.000000-nCBFreg-25487',
    'Data/manifest-1542731028231/Brain-Tumor-Progression/PGBM-002/08-13-1996-NA-Mr Rcbv Sequence-46313/37921.000000-T2reg-58639',
    'Data/manifest-1542731028231/Brain-Tumor-Progression/PGBM-002/01-17-1997-NA-MR RCBV SEQUENCE-36058/37916.000000-T2reg-88910',
    'Data/manifest-1542731028231/Brain-Tumor-Progression/PGBM-002/01-17-1997-NA-MR RCBV SEQUENCE-36058/5396.000000-MaskTumor-36321',
    'Data/manifest-1542731028231/Brain-Tumor-Progression/PGBM-002/01-17-1997-NA-MR RCBV SEQUENCE-36058/5396.000000-MaskTumor-36321'
    
]

# 각 폴더에 대해 4줄 x 5열 배열로 시각화
for folder_path in sequence_folders:
    # 새로운 figure 생성 (4줄 x 5열)
    fig, axs = plt.subplots(4, 5, figsize=(15, 12))  # 4줄, 5열로 20개 subplot
    axs = axs.flatten()  # 2D 배열을 1D 배열로 변환해 순차적으로 접근

    # 폴더 이름을 표시
    folder_name = os.path.basename(os.path.normpath(folder_path))  # 폴더 이름 추출
    fig.suptitle(f"Folder: {folder_name}", fontsize=16)

    # 각 폴더에서 최대 20개 DICOM 파일을 열어봅니다.
    for i, file_name in enumerate(sorted(os.listdir(folder_path))[:20]):  # 각 폴더에서 최대 20개 파일 시각화
        file_path = os.path.join(folder_path, file_name)
        
        # DICOM 파일 읽기 및 시각화
        try:
            dataset = pydicom.dcmread(file_path)
            axs[i].imshow(dataset.pixel_array, cmap='gray')  # 이미지를 흑백으로 표시
            axs[i].axis('off')  # 축 없애기
            axs[i].set_title(f"{file_name}", fontsize=8)  # 파일 이름을 제목으로 표시
        except Exception as e:
            print(f"Error reading {file_name} in folder {folder_path}: {e}")
            axs[i].axis('off')
            axs[i].set_title(f"Error {file_name}", fontsize=8)

    plt.tight_layout()
    plt.show()

# %%
# 각 시퀀스 폴더 경로
import pydicom
import matplotlib.pyplot as plt
import os

sequence_folders = [
    'Data/manifest-1542731028231/Brain-Tumor-Progression/PGBM-002/08-13-1996-NA-Mr Rcbv Sequence-46313/11.000000-T1post-73420',
    'Data/manifest-1542731028231/Brain-Tumor-Progression/PGBM-002/01-17-1997-NA-MR RCBV SEQUENCE-36058/12.000000-T1post-05670',
    'Data/manifest-1542731028231/Brain-Tumor-Progression/PGBM-002/08-13-1996-NA-Mr Rcbv Sequence-46313/14409.000000-dT1-29077',
    'Data/manifest-1542731028231/Brain-Tumor-Progression/PGBM-002/01-17-1997-NA-MR RCBV SEQUENCE-36058/29905.000000-dT1-93274',
    'Data/manifest-1542731028231/Brain-Tumor-Progression/PGBM-002/08-13-1996-NA-Mr Rcbv Sequence-46313/19446.000000-T1prereg-51935',
    'Data/manifest-1542731028231/Brain-Tumor-Progression/PGBM-002/01-17-1997-NA-MR RCBV SEQUENCE-36058/34909.000000-T1prereg-84610',
    'Data/manifest-1542731028231/Brain-Tumor-Progression/PGBM-002/08-13-1996-NA-Mr Rcbv Sequence-46313/36449.000000-FLAIRreg-98695',
    'Data/manifest-1542731028231/Brain-Tumor-Progression/PGBM-002/01-17-1997-NA-MR RCBV SEQUENCE-36058/36459.000000-FLAIRreg-76244',
    'Data/manifest-1542731028231/Brain-Tumor-Progression/PGBM-002/08-13-1996-NA-Mr Rcbv Sequence-46313/36450.000000-ADCreg-95934',
    'Data/manifest-1542731028231/Brain-Tumor-Progression/PGBM-002/01-17-1997-NA-MR RCBV SEQUENCE-36058/36460.000000-ADCreg-72331',
    'Data/manifest-1542731028231/Brain-Tumor-Progression/PGBM-002/08-13-1996-NA-Mr Rcbv Sequence-46313/36454.000000-nRCBVreg-37925',
    'Data/manifest-1542731028231/Brain-Tumor-Progression/PGBM-002/01-17-1997-NA-MR RCBV SEQUENCE-36058/36465.000000-nRCBVreg-26072',
    'Data/manifest-1542731028231/Brain-Tumor-Progression/PGBM-002/08-13-1996-NA-Mr Rcbv Sequence-46313/36455.000000-sRCBVreg-00481',
    'Data/manifest-1542731028231/Brain-Tumor-Progression/PGBM-002/01-17-1997-NA-MR RCBV SEQUENCE-36058/36463.000000-sRCBVreg-80726',
    'Data/manifest-1542731028231/Brain-Tumor-Progression/PGBM-002/08-13-1996-NA-Mr Rcbv Sequence-46313/36456.000000-nCBFreg-05909',
    'Data/manifest-1542731028231/Brain-Tumor-Progression/PGBM-002/01-17-1997-NA-MR RCBV SEQUENCE-36058/36464.000000-nCBFreg-25487',
    'Data/manifest-1542731028231/Brain-Tumor-Progression/PGBM-002/08-13-1996-NA-Mr Rcbv Sequence-46313/37921.000000-T2reg-58639',
    'Data/manifest-1542731028231/Brain-Tumor-Progression/PGBM-002/01-17-1997-NA-MR RCBV SEQUENCE-36058/37916.000000-T2reg-88910',
    'Data/manifest-1542731028231/Brain-Tumor-Progression/PGBM-002/08-13-1996-NA-Mr Rcbv Sequence-46313/5394.000000-MaskTumor-12694',
    'Data/manifest-1542731028231/Brain-Tumor-Progression/PGBM-002/01-17-1997-NA-MR RCBV SEQUENCE-36058/5396.000000-MaskTumor-36321'
    
]

for folder_path in sequence_folders:
    # 새로운 figure 생성 (1줄 x 5열)
    fig, axs = plt.subplots(1, 5, figsize=(15, 3))  # 1줄, 5열로 5개 subplot

    # 폴더 이름을 표시
    folder_name = os.path.basename(os.path.normpath(folder_path))  # 폴더 이름 추출
    fig.suptitle(f"Folder: {folder_name}", fontsize=16)

    # 각 폴더에서 마지막 5개 DICOM 파일을 선택하여 시각화
    files = sorted(os.listdir(folder_path))[-5:]  # 마지막 5개의 파일 선택
    for i, file_name in enumerate(files):
        file_path = os.path.join(folder_path, file_name)
        
        # DICOM 파일 읽기 및 시각화
        try:
            dataset = pydicom.dcmread(file_path)
            axs[i].imshow(dataset.pixel_array, cmap='gray')  # 이미지를 흑백으로 표시
            axs[i].axis('off')  # 축 없애기
            axs[i].set_title(f"{file_name}", fontsize=8)  # 파일 이름을 제목으로 표시
        except Exception as e:
            print(f"Error reading {file_name} in folder {folder_path}: {e}")
            axs[i].axis('off')
            axs[i].set_title(f"Error {file_name}", fontsize=8)

    plt.tight_layout()
    plt.show()

# %% [markdown]
# ### **[Three-dimensional visualization of brain tumor progression based accurate segmentation via comparative holographic projection](https://journals.plos.org/plosone/article?id=10.1371/journal.pone.0236835)** 을 보고 T1post 데이터셋을 사용하기로 했다. ###

# %%
# 각 시퀀스 폴더 경로
sequence_folders = [
    'Data/manifest-1542731028231/Brain-Tumor-Progression/PGBM-002/08-13-1996-NA-Mr Rcbv Sequence-46313/11.000000-T1post-73420',
    'Data/manifest-1542731028231/Brain-Tumor-Progression/PGBM-002/01-17-1997-NA-MR RCBV SEQUENCE-36058/12.000000-T1post-05670',
    #'Data/manifest-1542731028231/Brain-Tumor-Progression/PGBM-002/08-13-1996-NA-Mr Rcbv Sequence-46313/14409.000000-dT1-29077',
    #'Data/manifest-1542731028231/Brain-Tumor-Progression/PGBM-002/01-17-1997-NA-MR RCBV SEQUENCE-36058/29905.000000-dT1-93274',
    'Data/manifest-1542731028231/Brain-Tumor-Progression/PGBM-002/08-13-1996-NA-Mr Rcbv Sequence-46313/5394.000000-MaskTumor-12694',
    'Data/manifest-1542731028231/Brain-Tumor-Progression/PGBM-002/01-17-1997-NA-MR RCBV SEQUENCE-36058/5396.000000-MaskTumor-36321'
    
]

# 각 폴더에 대해 4줄 x 5열 배열로 시각화
for folder_path in sequence_folders:
    # 새로운 figure 생성 (4줄 x 5열)
    fig, axs = plt.subplots(4, 5, figsize=(15, 12))  # 4줄, 5열로 20개 subplot
    axs = axs.flatten()  # 2D 배열을 1D 배열로 변환해 순차적으로 접근

    # 폴더 이름을 표시
    folder_name = os.path.basename(os.path.normpath(folder_path))  # 폴더 이름 추출
    fig.suptitle(f"Folder: {folder_name}", fontsize=16)

    # 각 폴더에서 최대 20개 DICOM 파일을 열어봅니다.
    for i, file_name in enumerate(sorted(os.listdir(folder_path))[:20]):  # 각 폴더에서 최대 20개 파일 시각화
        file_path = os.path.join(folder_path, file_name)
        
        # DICOM 파일 읽기 및 시각화
        try:
            dataset = pydicom.dcmread(file_path)
            axs[i].imshow(dataset.pixel_array, cmap='gray')  # 이미지를 흑백으로 표시
            axs[i].axis('off')  # 축 없애기
            axs[i].set_title(f"{file_name}", fontsize=8)  # 파일 이름을 제목으로 표시
        except Exception as e:
            print(f"Error reading {file_name} in folder {folder_path}: {e}")
            axs[i].axis('off')
            axs[i].set_title(f"Error {file_name}", fontsize=8)

    plt.tight_layout()
    plt.show()

# %%
import pydicom

# DICOM 파일 경로
dicom_path = 'Data/manifest-1542731028231/Brain-Tumor-Progression/PGBM-001/04-02-1992-NA-FH-HEADBrain Protocols-79896/11.000000-T1post-80644/1-15.dcm'

# DICOM 파일 읽기
dicom_data = pydicom.dcmread(dicom_path)

# 이미지 해상도 확인
pixel_array = dicom_data.pixel_array
original_height, original_width = pixel_array.shape
print(f"Original Resolution: {original_width} x {original_height}")

# 픽셀 크기 정보 확인 (있을 경우)
if 'PixelSpacing' in dicom_data:
    pixel_spacing = dicom_data.PixelSpacing
    print(f"Pixel Spacing: {pixel_spacing[0]} mm x {pixel_spacing[1]} mm")
else:
    print("Pixel Spacing information is not available.")
# Out:
# Original Resolution: 260 x 320
# Pixel Spacing: 0.6875 mm x 0.6875 mm
